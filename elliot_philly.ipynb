# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/elliot_philly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data_philly.csv")
df2 = pd.read_csv("data_philly.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                              job    user project   state  \
# 0           0   application_1501012364013_9680  a547a3  6214e9  Killed
# 1           1  application_1501012364013_13894  e90b30  b436b2  Failed
# 2           2  application_1501012364013_16024  a4559a  6214e9  Killed
# 3           3  application_1501012364013_16024  a4559a  6214e9  Killed
# 4           4  application_1501012364013_16024  a4559a  6214e9  Killed
#
#    gpu_num  cpu_num  node_num   submit_time  wait_time   run_time  wall_time  \
# 0        1        0         1  1.502115e+09  3139935.0  1389243.0          0
# 1        8        0         4  1.502510e+09  2933963.0    14405.0          0
# 2        1        0         1  1.502768e+09  1570682.0    66336.0          0
# 3        1        0         1  1.502768e+09  1637023.0  1042044.0          0
# 4        1        0         1  1.502768e+09  2679080.0  2504635.0          0
#
#    node_hour  core_hour
# 0  1389243.0  1389243.0
# 1    57620.0   115240.0
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.head()
# Out:
#    Unnamed: 0                              job    user project   state  \
# 0           0   application_1501012364013_9680  a547a3  6214e9  Killed
# 1           1  application_1501012364013_13894  e90b30  b436b2  Failed
# 2           2  application_1501012364013_16024  a4559a  6214e9  Killed
# 3           3  application_1501012364013_16024  a4559a  6214e9  Killed
# 4           4  application_1501012364013_16024  a4559a  6214e9  Killed
#
#    gpu_num  cpu_num  node_num   submit_time  wait_time   run_time  wall_time  \
# 0        1        0         1 1502114581.00 3139935.00 1389243.00          0
# 1        8        0         4 1502509727.00 2933963.00   14405.00          0
# 2        1        0         1 1502767620.00 1570682.00   66336.00          0
# 3        1        0         1 1502767620.00 1637023.00 1042044.00          0
# 4        1        0         1 1502767620.00 2679080.00 2504635.00          0
#
#    node_hour  core_hour
# 0 1389243.00 1389243.00
# 1   57620.00  115240.00
# ...

# %%
df = df[["job", "submit_time", "wait_time", "run_time", "node_num", "wall_time"]]

# %%
df["used_memory"] = -1
df["requested_number_of_processors"] = -1
df["requested_time"] = -1
df["requested_memory"] = -1
df["status"] = -1
df["user_id"] = df2["user"]
df["group_id"] = -1
df["executable_number"] = -1
df["queue_number"] = -1
df["partition_number"] = -1
df["preceding_job_number"] = -1
df["think_time_from_preceding_job"] = -1

# %%
df.head()
# Out:
#                                job   submit_time  wait_time   run_time  \
# 0   application_1501012364013_9680 1502114581.00 3139935.00 1389243.00
# 1  application_1501012364013_13894 1502509727.00 2933963.00   14405.00
# 2  application_1501012364013_16024 1502767620.00 1570682.00   66336.00
# 3  application_1501012364013_16024 1502767620.00 1637023.00 1042044.00
# 4  application_1501012364013_16024 1502767620.00 2679080.00 2504635.00
#
#    node_num  wall_time  used_memory  requested_number_of_processors  \
# 0         1          0           -1                              -1
# 1         4          0           -1                              -1
# 2         1          0           -1                              -1
# 3         1          0           -1                              -1
# 4         1          0           -1                              -1
#
#    requested_time  requested_memory  status user_id  group_id  \
# 0              -1                -1      -1  a547a3        -1
# ...

# %%
from google.colab import files

# %%
df.to_csv("elliot_philly.csv")
df.to_csv("elliot_philly.txt")

# %%
files.download("elliot_philly.csv")
files.download("elliot_philly.txt")
