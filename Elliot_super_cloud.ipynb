# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/Elliot_super_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df = pd.read_csv("data_helios.csv")
df2 = pd.read_csv("data_helios.csv")
df.head()
# Out:
#    Unnamed: 0     job   user project   state  gpu_num  cpu_num  node_num  \
# 0           0  582026  u4TfD   vcWoR    Pass        1        1         1
# 1           1  582027  u4TfD   vcWoR    Pass        1        1         1
# 2           2  582028  u4TfD   vcWoR    Pass        1        1         1
# 3           3  582029  ubfUm   vcJLV  Failed        1        1         1
# 4           4  582030  uqOcl   vchbv    Pass        8       40         1
#
#     submit_time  wait_time  run_time  wall_time  node_hour  core_hour
# 0 1590638306.00       0.00     84.00          0      84.00      84.00
# 1 1590638400.00       0.00     87.00          0      87.00      87.00
# 2 1590638551.00       0.00     83.00          0      83.00      83.00
# 3 1590638658.00       0.00     30.00          0      30.00      30.00
# 4 1590638686.00       0.00    656.00          0     656.00    5248.00

# %%
df = df[["job", "submit_time", "wait_time", "run_time", "node_num", "wall_time"]]

# %%
df.head()
# Out:
#       job   submit_time  wait_time  run_time  node_num  wall_time
# 0  582026 1590638306.00       0.00     84.00         1          0
# 1  582027 1590638400.00       0.00     87.00         1          0
# 2  582028 1590638551.00       0.00     83.00         1          0
# 3  582029 1590638658.00       0.00     30.00         1          0
# 4  582030 1590638686.00       0.00    656.00         1          0

# %%
df["used_memory"] = -1
df["requested_number_of_processors"] = -1
df["requested_time"] = -1
df["requested_memory"] = -1
df["status"] = -1
df["user_id"] = df2["user"]
df["group_id"] = -1
df["executable_number"] = -1
df["queue_number"] = -1
df["partition_number"] = -1
df["preceding_job_number"] = -1
df["think_time_from_preceding_job"] = -1

# %%
df.head()
# Out:
#       job   submit_time  wait_time  run_time  node_num  wall_time  \
# 0  582026 1590638306.00       0.00     84.00         1          0
# 1  582027 1590638400.00       0.00     87.00         1          0
# 2  582028 1590638551.00       0.00     83.00         1          0
# 3  582029 1590638658.00       0.00     30.00         1          0
# 4  582030 1590638686.00       0.00    656.00         1          0
#
#    used_memory  requested_number_of_processors  requested_time  \
# 0           -1                              -1              -1
# 1           -1                              -1              -1
# 2           -1                              -1              -1
# 3           -1                              -1              -1
# 4           -1                              -1              -1
#
#    requested_memory  status user_id  group_id  executable_number  \
# 0                -1      -1   u4TfD        -1                 -1
# ...

# %%
df.to_csv("elliot_helios.csv")
from google.colab import files
files.download("elliot_helios.csv")

# %%
df.to_csv("elliot_helios.txt")
files.download("elliot_helios.txt")
