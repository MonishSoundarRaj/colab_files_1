# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/Meeting_9_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("data_supercloud.csv")
df2 = pd.read_csv("slurm-log.csv")
df.head(10)
# Out:
#    Unnamed: 0             job            user  project  state  gpu_num  \
# 0           0  82691694838059  42770088536256        0      3        0
# 1           1   3434806870797  42770088536256        0      3        0
# 2           2   8370846758272  42770088536256        0      3        0
# 3           3  50552783599355  28063009141185        0      5        0
# 4           4  16051179268048  42770088536256        0      3        0
# 5           5  26940411750496  78105663882022        0      5        0
# 6           6  26419036762941  11289836447956        0      3        0
# 7           7  84007780551106  11289836447956        0      3        0
# 8           8  18898577480687  11289836447956        0      3        0
# 9           9  16601813966475  11289836447956        0      3        0
#
#    cpu_num  node_num  submit_time  wait_time  run_time  wall_time  node_hour  \
# 0       20         1   1609535703     270594       308          0   0.085556
# ...

# %%
df2.head(10)
# Out:
#            id_job    id_array_job  id_array_task         id_user  \
# 0  82691694838059  38873353215144           2504  42770088536256
# 1   3434806870797  38873353215144           2523  42770088536256
# 2   8370846758272  38873353215144           2543  42770088536256
# 3  50552783599355  16618712154521     4294967294  28063009141185
# 4  16051179268048  74939912707152           2625  42770088536256
# 5  26940411750496  16618712154521     4294967294  78105663882022
# 6  26419036762941  84173100828392              0  11289836447956
# 7  84007780551106  84173100828392              1  11289836447956
# 8  18898577480687  84173100828392              2  11289836447956
# 9  16601813966475  84173100828392              3  11289836447956
#
#       kill_requid  nodes_alloc              nodelist  cpus_req  derived_ec  \
# 0  61026541062099            1  ['r9189566-n911952']        20           0
# 1  61026541062099            1  ['r9189566-n911952']        20           0
# ...

# %%
df["gpu_num"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 395909    0
# 395910    0
# 395911    0
# 395912    0
# 395913    0
# Name: gpu_num, Length: 395914, dtype: int64

# %%
df2.columns
# Out:
# Index(['id_job', 'id_array_job', 'id_array_task', 'id_user', 'kill_requid',
#        'nodes_alloc', 'nodelist', 'cpus_req', 'derived_ec', 'exit_code',
#        'gres_used', 'array_max_tasks', 'array_task_pending', 'constraints',
#        'flags', 'mem_req', 'partition', 'priority', 'state', 'timelimit',
#        'time_submit', 'time_eligible', 'time_start', 'time_end',
#        'time_suspended', 'track_steps', 'tres_alloc', 'tres_req', 'job_type'],
#       dtype='object')

# %%
df["node_num"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 395909    1
# 395910    1
# 395911    1
# 395912    1
# 395913    1
# Name: node_num, Length: 395914, dtype: int64

# %%
(df["node_num"] == 1).sum()
# Out:
# 389353

# %%
df[df["job"]>0]
# Out:
#         Unnamed: 0             job            user  project  state  gpu_num  \
# 0                0  82691694838059  42770088536256        0      3        0
# 1                1   3434806870797  42770088536256        0      3        0
# 2                2   8370846758272  42770088536256        0      3        0
# 3                3  50552783599355  28063009141185        0      5        0
# 4                4  16051179268048  42770088536256        0      3        0
# ...            ...             ...             ...      ...    ...      ...
# 395909      395909  32038172524356  11051103666595        0      3        0
# 395910      395910  70062821387698  11051103666595        0      3        0
# 395911      395911  39278200520145  11051103666595        0      3        0
# 395912      395912  20365469379943  11051103666595        0      3        0
# 395913      395913  70535025316763  11051103666595        0      3        0
#
# ...

# %%
df["user"].unique().size
# Out:
# 608

# %%
df2[df["gpu_num"]>0]
# Out:
#                 id_job    id_array_job  id_array_task         id_user  \
# 46366   79277366451042  16618712154521     4294967294  88319947881335
# 54485   57917922375098  16618712154521     4294967294   5042570016904
# 54500   57958873292129  16618712154521     4294967294   5042570016904
# 54674   30006685108544  16618712154521     4294967294  35641492241793
# 54867   14800946786555  16618712154521     4294967294  81003539624503
# ...                ...             ...            ...             ...
# 395847  39199408493487  16618712154521     4294967294  46497969842662
# 395860  29095436705999  16618712154521     4294967294  46497969842662
# 395874   6087930958249  16618712154521     4294967294  41862472687095
# 395896  82224899865640  54589468783704              1  85683288662927
# 395897  77615014380107  54589468783704              2  85683288662927
#
#            kill_requid  nodes_alloc                                  nodelist  \
# ...

# %%
df2[df2["nodes_alloc"]>800].iloc[0]['nodelist'].split(",")
# Out:
# ["['r7217787-n244243'",
#  " 'r4858666-n244243'",
#  " 'r8212643-n244243'",
#  " 'r189256-n244243'",
#  " 'r9352821-n244243'",
#  " 'r629115-n244243'",
#  " 'r7839831-n244243'",
#  " 'r6682735-n244243'",
#  " 'r3741709-n244243'",
#  " 'r8333645-n244243'",
#  " 'r2086368-n244243'",
#  " 'r9757054-n244243'",
#  " 'r1485405-n244243'",
#  " 'r7343737-n244243'",
#  " 'r9021574-n244243'",
#  " 'r3824475-n244243'",
#  " 'r9102715-n244243'",
#  " 'r9189566-n244243'",
#  " 'r1081020-n244243'",
#  " 'r3581284-n244243'",
#  " 'r2652301-n244243'",
#  " 'r5189505-n244243'",
#  " 'r29114-n244243'",
#  " 'r9026042-n244243'",
#  " 'r9192091-n244243'",
#  " 'r3226521-n244243'",
#  " 'r697496-n244243'",
#  " 'r7952476-n244243'",
#  " 'r8937440-n244243'",
#  " 'r3041626-n244243'",
#  " 'r9273661-n244243'",
#  " 'r4247208-n244243'",
#  " 'r1682297-n244243'",
#  " 'r6760045-n244243'",
#  " 'r6341586-n244243'",
#  " 'r1018283-n244243'",
#  " 'r3475376-n935848'",
#  " 'r4327055-n935848'",
# ...
