# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/th_data_log_rc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
df = pd.read_csv('theta_datalog.csv')
df.head()
# Out:
#        JOB_NAME  COBALT_JOBID MACHINE_NAME     QUEUED_TIMESTAMP  \
# 0  639487.theta        639487        theta  2022-12-31 23:28:21
# 1  639448.theta        639448        theta  2022-12-31 17:30:46
# 2  639135.theta        639135        theta  2022-12-27 21:00:46
# 3  638720.theta        638720        theta  2022-12-24 18:04:32
# 4  639463.theta        639463        theta  2022-12-31 19:12:30
#
#    QUEUED_DATE_ID      START_TIMESTAMP  START_DATE_ID        END_TIMESTAMP  \
# 0        20221231  2022-12-31 23:29:32       20221231  2023-01-01 00:30:05
# 1        20221231  2022-12-31 19:40:18       20221231  2023-01-01 01:41:13
# 2        20221227  2022-12-31 19:43:38       20221231  2023-01-01 01:44:34
# 3        20221224  2023-01-01 01:46:34       20230101  2023-01-01 02:47:23
# 4        20221231  2023-01-01 01:42:54       20230101  2023-01-01 03:22:49
#
#    END_DATE_ID  USERNAME_GENID  ...  IS_SUBBLOCK IS_SUBBLOCK_ONLY  \
# 0     20230101    6.387939e+13  ...            0                0
# 1     20230101             NaN  ...            0                0
# 2     20230101    2.785630e+13  ...            0                0
# 3     20230101    7.200789e+13  ...            0                0
# 4     20230101             NaN  ...            0                0
#
#    IS_MULTILOCATION_ONLY  IS_MULTILOCATION_SUBBLOCK  IS_CONSECUTIVE_ONLY  \
# 0                      0                          0                    0
# 1                      0                          0                    0
# 2                      0                          0                    0
# 3                      0                          0                    0
# 4                      0                          0                    0
#
#    IS_SINGLE_ONLY  IS_NO_TASKS  IS_OTHER OVERBURN_CORE_HOURS  IS_OVERBURN
# 0               0            0         0              0.0000            0
# 1               0            0         0              0.0000            0
# 2               0            0         0              0.0000            0
# 3               0            0         0          16489.0468            1
# 4               0            0         0              0.0000            0
#
# [5 rows x 57 columns]

# %%
df["START_TIMESTAMP"].max()
# Out:
# '2023-07-28 11:53:56'

# %%
df["START_TIMESTAMP"].min()
# Out:
# '2022-12-31 19:40:18'

# %%
df['START_TIMESTAMP'] = pd.to_datetime(df['START_TIMESTAMP'])
start_date = '2023-03-28'
end_date = '2023-07-28'
df = df[(df['START_TIMESTAMP'] >= start_date) & (df['START_TIMESTAMP'] <= end_date)]

# %%
df.head()
# Out:
#            JOB_NAME  COBALT_JOBID MACHINE_NAME     QUEUED_TIMESTAMP  \
# 10259  650251.theta        650251        theta  2023-03-28 00:16:39
# 10260  650252.theta        650252        theta  2023-03-28 00:18:18
# 10262  650250.theta        650250        theta  2023-03-28 00:02:41
# 10263  650089.theta        650089        theta  2023-03-26 19:06:11
# 10264  649993.theta        649993        theta  2023-03-24 21:25:26
#
#        QUEUED_DATE_ID     START_TIMESTAMP  START_DATE_ID        END_TIMESTAMP  \
# 10259        20230328 2023-03-28 00:17:19       20230328  2023-03-28 00:18:12
# 10260        20230328 2023-03-28 00:18:51       20230328  2023-03-28 00:22:31
# 10262        20230328 2023-03-28 00:03:17       20230328  2023-03-28 01:00:17
# 10263        20230326 2023-03-28 02:00:08       20230328  2023-03-28 02:01:04
# 10264        20230324 2023-03-28 02:07:54       20230328  2023-03-28 02:08:53
#
#        END_DATE_ID  USERNAME_GENID  ...  IS_SUBBLOCK IS_SUBBLOCK_ONLY  \
# 10259     20230328    1.368506e+12  ...            0                0
# 10260     20230328    8.408399e+13  ...            0                0
# 10262     20230328             NaN  ...            0                0
# 10263     20230328    2.014983e+13  ...            0                0
# 10264     20230328    2.014983e+13  ...            0                0
#
#        IS_MULTILOCATION_ONLY  IS_MULTILOCATION_SUBBLOCK  IS_CONSECUTIVE_ONLY  \
# 10259                      0                          0                    0
# 10260                      0                          0                    0
# 10262                      0                          0                    0
# 10263                      0                          0                    0
# 10264                      0                          0                    0
#
#        IS_SINGLE_ONLY  IS_NO_TASKS  IS_OTHER OVERBURN_CORE_HOURS  IS_OVERBURN
# 10259               0            0         0                 0.0            0
# 10260               0            0         0                 0.0            0
# 10262               0            0         0                 0.0            0
# 10263               0            0         0                 0.0            0
# 10264               0            0         0                 0.0            0
#
# [5 rows x 57 columns]

# %%
df["START_TIMESTAMP"].max()
# Out:
# Timestamp('2023-07-27 22:32:11')

# %%
df["START_TIMESTAMP"].min()
# Out:
# Timestamp('2023-03-28 00:03:17')

# %%
df['START_TIMESTAMP'] = df['START_TIMESTAMP'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df["START_TIMESTAMP"].min()
# Out:
# '2023-03-28 00:03:17'

# %%
columns_names = df.columns
print(columns_names)
(df['CORES_USED'] == df['CORES_REQUESTED']).sum()
df['state'] = 0
df['gpu_num'] = 0
print(df['ELIGIBLE_WAIT_SECONDS'])
print(df['EXIT_STATUS'])
# Out:
# Index(['JOB_NAME', 'COBALT_JOBID', 'MACHINE_NAME', 'QUEUED_TIMESTAMP',
#        'QUEUED_DATE_ID', 'START_TIMESTAMP', 'START_DATE_ID', 'END_TIMESTAMP',
#        'END_DATE_ID', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'QUEUE_NAME',
#        'WALLTIME_SECONDS', 'RUNTIME_SECONDS', 'NODES_USED', 'NODES_REQUESTED',
#        'CORES_USED', 'CORES_REQUESTED', 'LOCATION', 'EXIT_STATUS',
#        'ELIGIBLE_WAIT_SECONDS', 'ELIGIBLE_WAIT_FACTOR', 'QUEUED_WAIT_SECONDS',
#        'QUEUED_WAIT_FACTOR', 'REQUESTED_CORE_HOURS', 'USED_CORE_HOURS',
#        'CAPABILITY_USAGE_CORE_HOURS', 'NONCAPABILITY_USAGE_CORE_HOURS',
#        'BUCKETS3_A_USAGE_CORE_HOURS', 'BUCKETS3_B_USAGE_CORE_HOURS',
#        'BUCKETS3_C_USAGE_CORE_HOURS', 'MACHINE_PARTITION', 'EXIT_CODE', 'MODE',
#        'RESID', 'DATA_LOAD_STATUS', 'CAPABILITY', 'SIZE_BUCKETS3',
#        'PERCENTILE', 'NUM_TASKS_SUBBLOCK', 'NUM_TASKS_CONSECUTIVE',
#        'NUM_TASKS_MULTILOCATION', 'NUM_TASKS_SINGLE', 'COBALT_NUM_TASKS',
#        'IS_SINGLE', 'IS_CONSECUTIVE', 'IS_MULTILOCATION', 'IS_SUBBLOCK',
#        'IS_SUBBLOCK_ONLY', 'IS_MULTILOCATION_ONLY',
#        'IS_MULTILOCATION_SUBBLOCK', 'IS_CONSECUTIVE_ONLY', 'IS_SINGLE_ONLY',
#        'IS_NO_TASKS', 'IS_OTHER', 'OVERBURN_CORE_HOURS', 'IS_OVERBURN'],
#       dtype='object')
# 10259         0
# 10260         0
# 10262         0
# 10263    111195
# 10264    276115
#           ...
# 23326         0
# 23327     96380
# 23328    126747
# 23331     98912
# 23347    146137
# Name: ELIGIBLE_WAIT_SECONDS, Length: 13070, dtype: int64
# 10259      0
# 10260    143
# 10262      0
# 10263    254
# 10264    254
#         ...
# 23326      0
# 23327      0
# 23328    143
# 23331    143
# 23347    143
# Name: EXIT_STATUS, Length: 13070, dtype: int64

# %%
df = df[['JOB_NAME', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'state', 'gpu_num', 'CORES_USED', 'NODES_USED', 'QUEUED_TIMESTAMP', 'START_TIMESTAMP', 'RUNTIME_SECONDS', 'WALLTIME_SECONDS', 'EXIT_STATUS']]
df.columns
# Out:
# Index(['JOB_NAME', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'state', 'gpu_num',
#        'CORES_USED', 'NODES_USED', 'QUEUED_TIMESTAMP', 'START_TIMESTAMP',
#        'RUNTIME_SECONDS', 'WALLTIME_SECONDS', 'EXIT_STATUS'],
#       dtype='object')

# %%
df.head()
# Out:
#            JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259  650251.theta    1.368506e+12                 NaN      0        0
# 10260  650252.theta    8.408399e+13        2.137360e+13      0        0
# 10262  650250.theta             NaN                 NaN      0        0
# 10263  650089.theta    2.014983e+13                 NaN      0        0
# 10264  649993.theta    2.014983e+13                 NaN      0        0
#
#        CORES_USED  NODES_USED     QUEUED_TIMESTAMP      START_TIMESTAMP  \
# 10259       128.0         2.0  2023-03-28 00:16:39  2023-03-28 00:17:19
# 10260       128.0         2.0  2023-03-28 00:18:18  2023-03-28 00:18:51
# 10262       384.0         6.0  2023-03-28 00:02:41  2023-03-28 00:03:17
# 10263    237760.0      3715.0  2023-03-26 19:06:11  2023-03-28 02:00:08
# 10264    110400.0      1725.0  2023-03-24 21:25:26  2023-03-28 02:07:54
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS
# 10259            52.93             600.0            0
# 10260           219.76             300.0          143
# 10262          3419.95            3600.0            0
# 10263            56.31            7200.0          254
# 10264            58.63           86400.0          254

# %%
import datetime
import pytz

def string_to_timestamp(time_string):
    dt_object_naive = datetime.datetime.strptime(time_string, '%Y-%m-%d %H:%M:%S')

    cst = pytz.timezone('US/Central')
    dt_object = cst.localize(dt_object_naive)

    return int(dt_object.timestamp())

df['QUEUED_TIMESTAMP'] = df['QUEUED_TIMESTAMP'].apply(string_to_timestamp)
df['START_TIMESTAMP'] = df['START_TIMESTAMP'].apply(string_to_timestamp)

# %%
df.head()
# Out:
#            JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259  650251.theta    1.368506e+12                 NaN      0        0
# 10260  650252.theta    8.408399e+13        2.137360e+13      0        0
# 10262  650250.theta             NaN                 NaN      0        0
# 10263  650089.theta    2.014983e+13                 NaN      0        0
# 10264  649993.theta    2.014983e+13                 NaN      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS
# 10259            52.93             600.0            0
# 10260           219.76             300.0          143
# 10262          3419.95            3600.0            0
# 10263            56.31            7200.0          254
# 10264            58.63           86400.0          254

# %%
df['PROJECT_NAME_GENID'] = df['PROJECT_NAME_GENID'].fillna(0)
df['USERNAME_GENID'] = df['PROJECT_NAME_GENID'].fillna(0)
df['state'] = df['state'].fillna(0)
df['gpu_num'] = df['gpu_num'].fillna(0)

# %%
df.head()
# Out:
#            JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259  650251.theta    0.000000e+00        0.000000e+00      0        0
# 10260  650252.theta    2.137360e+13        2.137360e+13      0        0
# 10262  650250.theta    0.000000e+00        0.000000e+00      0        0
# 10263  650089.theta    0.000000e+00        0.000000e+00      0        0
# 10264  649993.theta    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS
# 10259            52.93             600.0            0
# 10260           219.76             300.0          143
# 10262          3419.95            3600.0            0
# 10263            56.31            7200.0          254
# 10264            58.63           86400.0          254

# %%
df['JOB_NAME'] = df['JOB_NAME'].str.split('.').str[0]
df.head()
# Out:
#       JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259   650251    0.000000e+00        0.000000e+00      0        0
# 10260   650252    2.137360e+13        2.137360e+13      0        0
# 10262   650250    0.000000e+00        0.000000e+00      0        0
# 10263   650089    0.000000e+00        0.000000e+00      0        0
# 10264   649993    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS
# 10259            52.93             600.0            0
# 10260           219.76             300.0          143
# 10262          3419.95            3600.0            0
# 10263            56.31            7200.0          254
# 10264            58.63           86400.0          254

# %%
# Can be used for wait time
df['wait_time'] = df['START_TIMESTAMP']-df['QUEUED_TIMESTAMP']
df.head()
# Out:
#       JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259   650251    0.000000e+00        0.000000e+00      0        0
# 10260   650252    2.137360e+13        2.137360e+13      0        0
# 10262   650250    0.000000e+00        0.000000e+00      0        0
# 10263   650089    0.000000e+00        0.000000e+00      0        0
# 10264   649993    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS  wait_time
# 10259            52.93             600.0            0         40
# 10260           219.76             300.0          143         33
# 10262          3419.95            3600.0            0         36
# 10263            56.31            7200.0          254     111237
# 10264            58.63           86400.0          254     276148

# %%
len(df)
# Out:
# 13070

# %%
print(df['NODES_USED'].dtypes)
print(df['RUNTIME_SECONDS'].dtypes)

df['node_hour'] = df['NODES_USED'] * df['RUNTIME_SECONDS']
# Out:
# float64
# float64

# %%
df.head()
# Out:
#       JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259   650251    0.000000e+00        0.000000e+00      0        0
# 10260   650252    2.137360e+13        2.137360e+13      0        0
# 10262   650250    0.000000e+00        0.000000e+00      0        0
# 10263   650089    0.000000e+00        0.000000e+00      0        0
# 10264   649993    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS  wait_time  node_hour
# 10259            52.93             600.0            0         40     105.86
# 10260           219.76             300.0          143         33     439.52
# 10262          3419.95            3600.0            0         36   20519.70
# 10263            56.31            7200.0          254     111237  209191.65
# 10264            58.63           86400.0          254     276148  101136.75

# %%
df['node_hour'] = df['node_hour']/3600

# %%
df.head()
# Out:
#       JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259   650251    0.000000e+00        0.000000e+00      0        0
# 10260   650252    2.137360e+13        2.137360e+13      0        0
# 10262   650250    0.000000e+00        0.000000e+00      0        0
# 10263   650089    0.000000e+00        0.000000e+00      0        0
# 10264   649993    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS  wait_time  node_hour
# 10259            52.93             600.0            0         40   0.029406
# 10260           219.76             300.0          143         33   0.122089
# 10262          3419.95            3600.0            0         36   5.699917
# 10263            56.31            7200.0          254     111237  58.108792
# 10264            58.63           86400.0          254     276148  28.093542

# %%
df['EXIT_STATUS'].unique()
# Out:
# array([  0, 143, 254,   1, 137,   8, 255, 134, 127,   2,  59,   3,  24,
#        126, 135, 139, 120])

# %%
def code_to_status(code):
  if code == 0:
    return 'Pass'
  elif code == 137:
    return 'Killed'
  elif code == 143:
    return 'Killed'
  else:
    return 'Failed'

df['new_status'] = df['EXIT_STATUS'].apply(code_to_status)

# %%
df['new_status'].unique()
# Out:
# array(['Pass', 'Killed', 'Failed'], dtype=object)

# %%
df.head()
# Out:
#       JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259   650251    0.000000e+00        0.000000e+00      0        0
# 10260   650252    2.137360e+13        2.137360e+13      0        0
# 10262   650250    0.000000e+00        0.000000e+00      0        0
# 10263   650089    0.000000e+00        0.000000e+00      0        0
# 10264   649993    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  \
# 10259       128.0         2.0        1679980599       1679980639
# 10260       128.0         2.0        1679980698       1679980731
# 10262       384.0         6.0        1679979761       1679979797
# 10263    237760.0      3715.0        1679875571       1679986808
# 10264    110400.0      1725.0        1679711126       1679987274
#
#        RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS  wait_time  node_hour  \
# 10259            52.93             600.0            0         40   0.029406
# 10260           219.76             300.0          143         33   0.122089
# 10262          3419.95            3600.0            0         36   5.699917
# 10263            56.31            7200.0          254     111237  58.108792
# 10264            58.63           86400.0          254     276148  28.093542
#
#       new_status
# 10259       Pass
# 10260     Killed
# 10262       Pass
# 10263     Failed
# 10264     Failed

# %%
df = df[['JOB_NAME', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'state', 'gpu_num', 'CORES_USED', 'NODES_USED', 'QUEUED_TIMESTAMP', 'wait_time', 'RUNTIME_SECONDS', 'WALLTIME_SECONDS', 'node_hour', 'new_status']]
df.head()
# Out:
#       JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 10259   650251    0.000000e+00        0.000000e+00      0        0
# 10260   650252    2.137360e+13        2.137360e+13      0        0
# 10262   650250    0.000000e+00        0.000000e+00      0        0
# 10263   650089    0.000000e+00        0.000000e+00      0        0
# 10264   649993    0.000000e+00        0.000000e+00      0        0
#
#        CORES_USED  NODES_USED  QUEUED_TIMESTAMP  wait_time  RUNTIME_SECONDS  \
# 10259       128.0         2.0        1679980599         40            52.93
# 10260       128.0         2.0        1679980698         33           219.76
# 10262       384.0         6.0        1679979761         36          3419.95
# 10263    237760.0      3715.0        1679875571     111237            56.31
# 10264    110400.0      1725.0        1679711126     276148            58.63
#
#        WALLTIME_SECONDS  node_hour new_status
# 10259             600.0   0.029406       Pass
# 10260             300.0   0.122089     Killed
# 10262            3600.0   5.699917       Pass
# 10263            7200.0  58.108792     Failed
# 10264           86400.0  28.093542     Failed

# %%
df.columns = ['job', 'user', 'project', 'state', 'gpu_num', 'cpu_num', 'node_num', 'submit_time', 'wait_time', 'run_time', 'wall_time', 'node_hour', 'new_status']

# %%
df.head()
# Out:
#           job          user       project  state  gpu_num   cpu_num  node_num  \
# 10259  650251  0.000000e+00  0.000000e+00      0        0     128.0       2.0
# 10260  650252  2.137360e+13  2.137360e+13      0        0     128.0       2.0
# 10262  650250  0.000000e+00  0.000000e+00      0        0     384.0       6.0
# 10263  650089  0.000000e+00  0.000000e+00      0        0  237760.0    3715.0
# 10264  649993  0.000000e+00  0.000000e+00      0        0  110400.0    1725.0
#
#        submit_time  wait_time  run_time  wall_time  node_hour new_status
# 10259   1679980599         40     52.93      600.0   0.029406       Pass
# 10260   1679980698         33    219.76      300.0   0.122089     Killed
# 10262   1679979761         36   3419.95     3600.0   5.699917       Pass
# 10263   1679875571     111237     56.31     7200.0  58.108792     Failed
# 10264   1679711126     276148     58.63    86400.0  28.093542     Failed

# %%
df.to_csv('data_theta.csv')

# %%
files.download("data_theta.csv")

# %%
df2 = pd.read_csv("data_theta.csv")
df3 = pd.read_csv("data_theta_4.csv")

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'job', 'user', 'project', 'state', 'gpu_num', 'cpu_num',
#        'node_num', 'submit_time', 'wait_time', 'run_time', 'wall_time',
#        'node_hour', 'new_status'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'job', 'user', 'project', 'state', 'gpu_num', 'cpu_num',
#        'node_num', 'submit_time', 'wait_time', 'run_time', 'wall_time',
#        'node_hour', 'new_status'],
#       dtype='object')

# %%
df3["submit_time"].max()
# Out:
# 1690515075

# %%
df2["submit_time"].max()
# Out:
# 1690545187
