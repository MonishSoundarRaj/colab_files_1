# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/th_data_log_rc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
df = pd.read_csv('theta_datalog.csv')
df.head()
# Out:
#        JOB_NAME  COBALT_JOBID MACHINE_NAME     QUEUED_TIMESTAMP  \
# 0  639487.theta        639487        theta  2022-12-31 23:28:21
# 1  639448.theta        639448        theta  2022-12-31 17:30:46
# 2  639135.theta        639135        theta  2022-12-27 21:00:46
# 3  638720.theta        638720        theta  2022-12-24 18:04:32
# 4  639463.theta        639463        theta  2022-12-31 19:12:30
#
#    QUEUED_DATE_ID      START_TIMESTAMP  START_DATE_ID        END_TIMESTAMP  \
# 0        20221231  2022-12-31 23:29:32       20221231  2023-01-01 00:30:05
# 1        20221231  2022-12-31 19:40:18       20221231  2023-01-01 01:41:13
# 2        20221227  2022-12-31 19:43:38       20221231  2023-01-01 01:44:34
# 3        20221224  2023-01-01 01:46:34       20230101  2023-01-01 02:47:23
# 4        20221231  2023-01-01 01:42:54       20230101  2023-01-01 03:22:49
#
#    END_DATE_ID  USERNAME_GENID  ...  IS_SUBBLOCK IS_SUBBLOCK_ONLY  \
# 0     20230101    6.387939e+13  ...            0                0
# 1     20230101             NaN  ...            0                0
# 2     20230101    2.785630e+13  ...            0                0
# 3     20230101    7.200789e+13  ...            0                0
# 4     20230101             NaN  ...            0                0
#
#    IS_MULTILOCATION_ONLY  IS_MULTILOCATION_SUBBLOCK  IS_CONSECUTIVE_ONLY  \
# 0                      0                          0                    0
# 1                      0                          0                    0
# 2                      0                          0                    0
# 3                      0                          0                    0
# 4                      0                          0                    0
#
#    IS_SINGLE_ONLY  IS_NO_TASKS  IS_OTHER OVERBURN_CORE_HOURS  IS_OVERBURN
# 0               0            0         0              0.0000            0
# 1               0            0         0              0.0000            0
# 2               0            0         0              0.0000            0
# 3               0            0         0          16489.0468            1
# 4               0            0         0              0.0000            0
#
# [5 rows x 57 columns]

# %%
df["START_TIMESTAMP"].max()
# Out:
# '2023-07-28 11:53:56'

# %%
df["START_TIMESTAMP"].min()
# Out:
# '2022-12-31 19:40:18'

# %%
df['START_TIMESTAMP'] = pd.to_datetime(df['START_TIMESTAMP'])
start_date = '2022-12-31'
end_date = '2023-04-30'
df = df[(df['START_TIMESTAMP'] >= start_date) & (df['START_TIMESTAMP'] <= end_date)]

# %%
df.head()
# Out:
#        JOB_NAME  COBALT_JOBID MACHINE_NAME     QUEUED_TIMESTAMP  \
# 0  639487.theta        639487        theta  2022-12-31 23:28:21
# 1  639448.theta        639448        theta  2022-12-31 17:30:46
# 2  639135.theta        639135        theta  2022-12-27 21:00:46
# 3  638720.theta        638720        theta  2022-12-24 18:04:32
# 4  639463.theta        639463        theta  2022-12-31 19:12:30
#
#    QUEUED_DATE_ID     START_TIMESTAMP  START_DATE_ID        END_TIMESTAMP  \
# 0        20221231 2022-12-31 23:29:32       20221231  2023-01-01 00:30:05
# 1        20221231 2022-12-31 19:40:18       20221231  2023-01-01 01:41:13
# 2        20221227 2022-12-31 19:43:38       20221231  2023-01-01 01:44:34
# 3        20221224 2023-01-01 01:46:34       20230101  2023-01-01 02:47:23
# 4        20221231 2023-01-01 01:42:54       20230101  2023-01-01 03:22:49
#
#    END_DATE_ID  USERNAME_GENID  ...  IS_SUBBLOCK IS_SUBBLOCK_ONLY  \
# 0     20230101    6.387939e+13  ...            0                0
# 1     20230101             NaN  ...            0                0
# 2     20230101    2.785630e+13  ...            0                0
# 3     20230101    7.200789e+13  ...            0                0
# 4     20230101             NaN  ...            0                0
#
#    IS_MULTILOCATION_ONLY  IS_MULTILOCATION_SUBBLOCK  IS_CONSECUTIVE_ONLY  \
# 0                      0                          0                    0
# 1                      0                          0                    0
# 2                      0                          0                    0
# 3                      0                          0                    0
# 4                      0                          0                    0
#
#    IS_SINGLE_ONLY  IS_NO_TASKS  IS_OTHER OVERBURN_CORE_HOURS  IS_OVERBURN
# 0               0            0         0              0.0000            0
# 1               0            0         0              0.0000            0
# 2               0            0         0              0.0000            0
# 3               0            0         0          16489.0468            1
# 4               0            0         0              0.0000            0
#
# [5 rows x 57 columns]

# %%
df["START_TIMESTAMP"].max()
# Out:
# Timestamp('2023-04-29 23:23:11')

# %%
df["START_TIMESTAMP"].min()
# Out:
# Timestamp('2022-12-31 19:40:18')

# %%
df['START_TIMESTAMP'] = df['START_TIMESTAMP'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df["START_TIMESTAMP"].min()
# Out:
# '2022-12-31 19:40:18'

# %%
columns_names = df.columns
print(columns_names)
(df['CORES_USED'] == df['CORES_REQUESTED']).sum()
df['state'] = 0
df['gpu_num'] = 0
print(df['ELIGIBLE_WAIT_SECONDS'])
print(df['EXIT_STATUS'])
# Out:
# Index(['JOB_NAME', 'COBALT_JOBID', 'MACHINE_NAME', 'QUEUED_TIMESTAMP',
#        'QUEUED_DATE_ID', 'START_TIMESTAMP', 'START_DATE_ID', 'END_TIMESTAMP',
#        'END_DATE_ID', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'QUEUE_NAME',
#        'WALLTIME_SECONDS', 'RUNTIME_SECONDS', 'NODES_USED', 'NODES_REQUESTED',
#        'CORES_USED', 'CORES_REQUESTED', 'LOCATION', 'EXIT_STATUS',
#        'ELIGIBLE_WAIT_SECONDS', 'ELIGIBLE_WAIT_FACTOR', 'QUEUED_WAIT_SECONDS',
#        'QUEUED_WAIT_FACTOR', 'REQUESTED_CORE_HOURS', 'USED_CORE_HOURS',
#        'CAPABILITY_USAGE_CORE_HOURS', 'NONCAPABILITY_USAGE_CORE_HOURS',
#        'BUCKETS3_A_USAGE_CORE_HOURS', 'BUCKETS3_B_USAGE_CORE_HOURS',
#        'BUCKETS3_C_USAGE_CORE_HOURS', 'MACHINE_PARTITION', 'EXIT_CODE', 'MODE',
#        'RESID', 'DATA_LOAD_STATUS', 'CAPABILITY', 'SIZE_BUCKETS3',
#        'PERCENTILE', 'NUM_TASKS_SUBBLOCK', 'NUM_TASKS_CONSECUTIVE',
#        'NUM_TASKS_MULTILOCATION', 'NUM_TASKS_SINGLE', 'COBALT_NUM_TASKS',
#        'IS_SINGLE', 'IS_CONSECUTIVE', 'IS_MULTILOCATION', 'IS_SUBBLOCK',
#        'IS_SUBBLOCK_ONLY', 'IS_MULTILOCATION_ONLY',
#        'IS_MULTILOCATION_SUBBLOCK', 'IS_CONSECUTIVE_ONLY', 'IS_SINGLE_ONLY',
#        'IS_NO_TASKS', 'IS_OTHER', 'OVERBURN_CORE_HOURS', 'IS_OVERBURN'],
#       dtype='object')
# 0            37
# 1          7731
# 2        340933
# 3        632482
# 4         23386
#           ...
# 13604      3540
# 13605      4343
# 13615    114751
# 13678        39
# 13697      1657
# Name: ELIGIBLE_WAIT_SECONDS, Length: 13607, dtype: int64
# 0        143
# 1          0
# 2        143
# 3        143
# 4          0
#         ...
# 13604      0
# 13605      0
# 13615      0
# 13678    127
# 13697      0
# Name: EXIT_STATUS, Length: 13607, dtype: int64

# %%
df = df[['JOB_NAME', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'state', 'gpu_num', 'CORES_USED', 'NODES_USED', 'QUEUED_TIMESTAMP', 'START_TIMESTAMP', 'RUNTIME_SECONDS', 'WALLTIME_SECONDS', 'EXIT_STATUS']]
df.columns
# Out:
# Index(['JOB_NAME', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'state', 'gpu_num',
#        'CORES_USED', 'NODES_USED', 'QUEUED_TIMESTAMP', 'START_TIMESTAMP',
#        'RUNTIME_SECONDS', 'WALLTIME_SECONDS', 'EXIT_STATUS'],
#       dtype='object')

# %%
df.head()
# Out:
#        JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 0  639487.theta    6.387939e+13                 NaN      0        0
# 1  639448.theta             NaN                 NaN      0        0
# 2  639135.theta    2.785630e+13                 NaN      0        0
# 3  638720.theta    7.200789e+13        7.029633e+13      0        0
# 4  639463.theta             NaN                 NaN      0        0
#
#    CORES_USED  NODES_USED     QUEUED_TIMESTAMP      START_TIMESTAMP  \
# 0       512.0         8.0  2022-12-31 23:28:21  2022-12-31 23:29:32
# 1     16384.0       256.0  2022-12-31 17:30:46  2022-12-31 19:40:18
# 2    262144.0      4096.0  2022-12-27 21:00:46  2022-12-31 19:43:38
# 3    262144.0      4096.0  2022-12-24 18:04:32  2023-01-01 01:46:34
# 4      8192.0       128.0  2022-12-31 19:12:30  2023-01-01 01:42:54
#
#    RUNTIME_SECONDS  WALLTIME_SECONDS  EXIT_STATUS
# 0          3632.92            3600.0          143
# 1         21654.66           21600.0            0
# 2         21655.97           21600.0          143
# 3          3648.70            3600.0          143
# 4          5995.18           10800.0            0

# %%
import datetime

def string_to_timestamp(time_string):
    dt_object = datetime.datetime.strptime(time_string, '%Y-%m-%d %H:%M:%S')
    return int(dt_object.timestamp())

df['QUEUED_TIMESTAMP'] = df['QUEUED_TIMESTAMP'].apply(string_to_timestamp)
df['START_TIMESTAMP'] = df['START_TIMESTAMP'].apply(string_to_timestamp)

# %%
df.head()
# Out:
#        JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 0  639487.theta    6.387939e+13                 NaN      0        0
# 1  639448.theta             NaN                 NaN      0        0
# 2  639135.theta    2.785630e+13                 NaN      0        0
# 3  638720.theta    7.200789e+13        7.029633e+13      0        0
# 4  639463.theta             NaN                 NaN      0        0
#
#    CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0       512.0         8.0        1672529301       1672529372          3632.92
# 1     16384.0       256.0        1672507846       1672515618         21654.66
# 2    262144.0      4096.0        1672174846       1672515818         21655.97
# 3    262144.0      4096.0        1671905072       1672537594          3648.70
# 4      8192.0       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS
# 0            3600.0          143
# 1           21600.0            0
# 2           21600.0          143
# 3            3600.0          143
# 4           10800.0            0

# %%
df['PROJECT_NAME_GENID'] = df['PROJECT_NAME_GENID'].fillna(0)
df['USERNAME_GENID'] = df['PROJECT_NAME_GENID'].fillna(0)
df['state'] = df['state'].fillna(0)
df['gpu_num'] = df['gpu_num'].fillna(0)

# %%
df.head()
# Out:
#        JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  \
# 0  639487.theta    0.000000e+00        0.000000e+00      0        0
# 1  639448.theta    0.000000e+00        0.000000e+00      0        0
# 2  639135.theta    0.000000e+00        0.000000e+00      0        0
# 3  638720.theta    7.029633e+13        7.029633e+13      0        0
# 4  639463.theta    0.000000e+00        0.000000e+00      0        0
#
#    CORES_USED  NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0       512.0         8.0        1672529301       1672529372          3632.92
# 1     16384.0       256.0        1672507846       1672515618         21654.66
# 2    262144.0      4096.0        1672174846       1672515818         21655.97
# 3    262144.0      4096.0        1671905072       1672537594          3648.70
# 4      8192.0       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS
# 0            3600.0          143
# 1           21600.0            0
# 2           21600.0          143
# 3            3600.0          143
# 4           10800.0            0

# %%
df['JOB_NAME'] = df['JOB_NAME'].str.split('.').str[0]
df.head()
# Out:
#   JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  CORES_USED  \
# 0   639487    0.000000e+00        0.000000e+00      0        0       512.0
# 1   639448    0.000000e+00        0.000000e+00      0        0     16384.0
# 2   639135    0.000000e+00        0.000000e+00      0        0    262144.0
# 3   638720    7.029633e+13        7.029633e+13      0        0    262144.0
# 4   639463    0.000000e+00        0.000000e+00      0        0      8192.0
#
#    NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0         8.0        1672529301       1672529372          3632.92
# 1       256.0        1672507846       1672515618         21654.66
# 2      4096.0        1672174846       1672515818         21655.97
# 3      4096.0        1671905072       1672537594          3648.70
# 4       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS
# 0            3600.0          143
# 1           21600.0            0
# 2           21600.0          143
# 3            3600.0          143
# 4           10800.0            0

# %%
# Can be used for wait time
df['wait_time'] = df['START_TIMESTAMP']-df['QUEUED_TIMESTAMP']
df.head()
# Out:
#   JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  CORES_USED  \
# 0   639487    0.000000e+00        0.000000e+00      0        0       512.0
# 1   639448    0.000000e+00        0.000000e+00      0        0     16384.0
# 2   639135    0.000000e+00        0.000000e+00      0        0    262144.0
# 3   638720    7.029633e+13        7.029633e+13      0        0    262144.0
# 4   639463    0.000000e+00        0.000000e+00      0        0      8192.0
#
#    NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0         8.0        1672529301       1672529372          3632.92
# 1       256.0        1672507846       1672515618         21654.66
# 2      4096.0        1672174846       1672515818         21655.97
# 3      4096.0        1671905072       1672537594          3648.70
# 4       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS  wait_time
# 0            3600.0          143         71
# 1           21600.0            0       7772
# 2           21600.0          143     340972
# 3            3600.0          143     632522
# 4           10800.0            0      23424

# %%
len(df)
# Out:
# 13607

# %%
print(df['NODES_USED'].dtypes)
print(df['RUNTIME_SECONDS'].dtypes)

df['node_hour'] = df['NODES_USED'] * df['RUNTIME_SECONDS']
# Out:
# float64
# float64

# %%
df.head()
# Out:
#   JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  CORES_USED  \
# 0   639487    0.000000e+00        0.000000e+00      0        0       512.0
# 1   639448    0.000000e+00        0.000000e+00      0        0     16384.0
# 2   639135    0.000000e+00        0.000000e+00      0        0    262144.0
# 3   638720    7.029633e+13        7.029633e+13      0        0    262144.0
# 4   639463    0.000000e+00        0.000000e+00      0        0      8192.0
#
#    NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0         8.0        1672529301       1672529372          3632.92
# 1       256.0        1672507846       1672515618         21654.66
# 2      4096.0        1672174846       1672515818         21655.97
# 3      4096.0        1671905072       1672537594          3648.70
# 4       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS  wait_time    node_hour
# 0            3600.0          143         71     29063.36
# 1           21600.0            0       7772   5543592.96
# 2           21600.0          143     340972  88702853.12
# 3            3600.0          143     632522  14945075.20
# 4           10800.0            0      23424    767383.04

# %%
df['node_hour'] = df['node_hour']/3600

# %%
df.head()
# Out:
#   JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  CORES_USED  \
# 0   639487    0.000000e+00        0.000000e+00      0        0       512.0
# 1   639448    0.000000e+00        0.000000e+00      0        0     16384.0
# 2   639135    0.000000e+00        0.000000e+00      0        0    262144.0
# 3   638720    7.029633e+13        7.029633e+13      0        0    262144.0
# 4   639463    0.000000e+00        0.000000e+00      0        0      8192.0
#
#    NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0         8.0        1672529301       1672529372          3632.92
# 1       256.0        1672507846       1672515618         21654.66
# 2      4096.0        1672174846       1672515818         21655.97
# 3      4096.0        1671905072       1672537594          3648.70
# 4       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS  wait_time     node_hour
# 0            3600.0          143         71      8.073156
# 1           21600.0            0       7772   1539.886933
# 2           21600.0          143     340972  24639.681422
# 3            3600.0          143     632522   4151.409778
# 4           10800.0            0      23424    213.161956

# %%
df['EXIT_STATUS'].unique()
# Out:
# array([143,   0, 137,   1, 127, 255,   8,   3, 134,  19,  24,   2, 130,
#        135, 136, 139, 174, 126, 168,  53,  74,  10, 256, 254,  59])

# %%
def code_to_status(code):
  if code == 0:
    return 'Pass'
  elif code == 137:
    return 'Killed'
  elif code == 143:
    return 'Killed'
  else:
    return 'Failed'

df['new_status'] = df['EXIT_STATUS'].apply(code_to_status)

# %%
df['new_status'].unique()
# Out:
# array(['Killed', 'Pass', 'Failed'], dtype=object)

# %%
df.head()
# Out:
#   JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  CORES_USED  \
# 0   639487    0.000000e+00        0.000000e+00      0        0       512.0
# 1   639448    0.000000e+00        0.000000e+00      0        0     16384.0
# 2   639135    0.000000e+00        0.000000e+00      0        0    262144.0
# 3   638720    7.029633e+13        7.029633e+13      0        0    262144.0
# 4   639463    0.000000e+00        0.000000e+00      0        0      8192.0
#
#    NODES_USED  QUEUED_TIMESTAMP  START_TIMESTAMP  RUNTIME_SECONDS  \
# 0         8.0        1672529301       1672529372          3632.92
# 1       256.0        1672507846       1672515618         21654.66
# 2      4096.0        1672174846       1672515818         21655.97
# 3      4096.0        1671905072       1672537594          3648.70
# 4       128.0        1672513950       1672537374          5995.18
#
#    WALLTIME_SECONDS  EXIT_STATUS  wait_time     node_hour new_status
# 0            3600.0          143         71      8.073156     Killed
# 1           21600.0            0       7772   1539.886933       Pass
# 2           21600.0          143     340972  24639.681422     Killed
# 3            3600.0          143     632522   4151.409778     Killed
# 4           10800.0            0      23424    213.161956       Pass

# %%
df = df[['JOB_NAME', 'USERNAME_GENID', 'PROJECT_NAME_GENID', 'state', 'gpu_num', 'CORES_USED', 'NODES_USED', 'QUEUED_TIMESTAMP', 'wait_time', 'RUNTIME_SECONDS', 'WALLTIME_SECONDS', 'node_hour', 'new_status']]
df.head()
# Out:
#   JOB_NAME  USERNAME_GENID  PROJECT_NAME_GENID  state  gpu_num  CORES_USED  \
# 0   639487    0.000000e+00        0.000000e+00      0        0       512.0
# 1   639448    0.000000e+00        0.000000e+00      0        0     16384.0
# 2   639135    0.000000e+00        0.000000e+00      0        0    262144.0
# 3   638720    7.029633e+13        7.029633e+13      0        0    262144.0
# 4   639463    0.000000e+00        0.000000e+00      0        0      8192.0
#
#    NODES_USED  QUEUED_TIMESTAMP  wait_time  RUNTIME_SECONDS  WALLTIME_SECONDS  \
# 0         8.0        1672529301         71          3632.92            3600.0
# 1       256.0        1672507846       7772         21654.66           21600.0
# 2      4096.0        1672174846     340972         21655.97           21600.0
# 3      4096.0        1671905072     632522          3648.70            3600.0
# 4       128.0        1672513950      23424          5995.18           10800.0
#
#       node_hour new_status
# 0      8.073156     Killed
# 1   1539.886933       Pass
# 2  24639.681422     Killed
# 3   4151.409778     Killed
# 4    213.161956       Pass

# %%
df.columns = ['job', 'user', 'project', 'state', 'gpu_num', 'cpu_num', 'node_num', 'submit_time', 'wait_time', 'run_time', 'wall_time', 'node_hour', 'new_status']

# %%
df.head()
# Out:
#       job          user       project  state  gpu_num   cpu_num  node_num  \
# 0  639487  0.000000e+00  0.000000e+00      0        0     512.0       8.0
# 1  639448  0.000000e+00  0.000000e+00      0        0   16384.0     256.0
# 2  639135  0.000000e+00  0.000000e+00      0        0  262144.0    4096.0
# 3  638720  7.029633e+13  7.029633e+13      0        0  262144.0    4096.0
# 4  639463  0.000000e+00  0.000000e+00      0        0    8192.0     128.0
#
#    submit_time  wait_time  run_time  wall_time     node_hour new_status
# 0   1672529301         71   3632.92     3600.0      8.073156     Killed
# 1   1672507846       7772  21654.66    21600.0   1539.886933       Pass
# 2   1672174846     340972  21655.97    21600.0  24639.681422     Killed
# 3   1671905072     632522   3648.70     3600.0   4151.409778     Killed
# 4   1672513950      23424   5995.18    10800.0    213.161956       Pass

# %%
df.to_csv('data_theta.csv')

# %%
files.download("data_theta.csv")
