# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/bluewaters_elliot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %%
import numpy as np

# %%
df = pd.read_csv("data_blue_waters.csv")
df.head(10)
df2 = pd.read_csv("data_blue_waters.csv")

# %%
df = df[["job", "submit_time", "wait_time", "run_time", "node_num", "wall_time"]]

# %%
df.head()
# Out:
#        job  submit_time  wait_time  run_time  node_num  wall_time
# 0  9090703   1539154542   11818241       233      2702      43200
# 1  9106378   1539558167   12363931       242      2702      43200
# 2  9329046   1544046589    2250476     57845        12      86400
# 3  9329047   1544046591    2308432     58188        12      86400
# 4  9329048   1544046593    2366688     57947        12      86400

# %%
df["used_memory"] = -1
df["requested_number_of_processors"] = -1
df["requested_time"] = -1
df["requested_memory"] = -1
df["status"] = -1
df["user_id"] = df2["user"]
df["group_id"] = -1
df["executable_number"] = -1
df["queue_number"] = -1
df["partition_number"] = -1
df["preceding_job_number"] = -1
df["think_time_from_preceding_job"] = -1
# Out:
# <ipython-input-11-b33515c3cd69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["used_memory"] = -1
# <ipython-input-11-b33515c3cd69>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["requested_number_of_processors"] = -1
# <ipython-input-11-b33515c3cd69>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head()
# Out:
#        job  submit_time  wait_time  run_time  node_num  wall_time  \
# 0  9090703   1539154542   11818241       233      2702      43200
# 1  9106378   1539558167   12363931       242      2702      43200
# 2  9329046   1544046589    2250476     57845        12      86400
# 3  9329047   1544046591    2308432     58188        12      86400
# 4  9329048   1544046593    2366688     57947        12      86400
#
#    used_memory  requested_number_of_processors  requested_time  \
# 0           -1                              -1              -1
# 1           -1                              -1              -1
# 2           -1                              -1              -1
# 3           -1                              -1              -1
# 4           -1                              -1              -1
#
#    requested_memory  status      user_id  group_id  executable_number  \
# 0                -1      -1  USER272409U        -1                 -1
# ...

# %%
df.to_csv("elliot_bluewaters.csv")
df.to_csv("elliot_bluewaters.txt")

# %%
files.download("elliot_bluewaters.csv")
files.download("elliot_bluewaters.txt")
