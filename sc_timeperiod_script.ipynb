# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/colab_files_1/blob/main/sc_timeperiod_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("slurm-log.csv")
df.head(50)
# Out:
#             id_job    id_array_job  id_array_task         id_user  \
# 0   82691694838059  38873353215144           2504  42770088536256
# 1    3434806870797  38873353215144           2523  42770088536256
# 2    8370846758272  38873353215144           2543  42770088536256
# 3   50552783599355  16618712154521     4294967294  28063009141185
# 4   16051179268048  74939912707152           2625  42770088536256
# 5   26940411750496  16618712154521     4294967294  78105663882022
# 6   26419036762941  84173100828392              0  11289836447956
# 7   84007780551106  84173100828392              1  11289836447956
# 8   18898577480687  84173100828392              2  11289836447956
# 9   16601813966475  84173100828392              3  11289836447956
# 10  38979333375258  84173100828392              4  11289836447956
# 11  35329673115911  84173100828392              5  11289836447956
# 12  24861103430782  84173100828392              6  11289836447956
# ...

# %%
(df["id_job"]>0).sum()
# Out:
# 395914

# %%
df.columns
# Out:
# Index(['id_job', 'id_array_job', 'id_array_task', 'id_user', 'kill_requid',
#        'nodes_alloc', 'nodelist', 'cpus_req', 'derived_ec', 'exit_code',
#        'gres_used', 'array_max_tasks', 'array_task_pending', 'constraints',
#        'flags', 'mem_req', 'partition', 'priority', 'state', 'timelimit',
#        'time_submit', 'time_eligible', 'time_start', 'time_end',
#        'time_suspended', 'track_steps', 'tres_alloc', 'tres_req', 'job_type'],
#       dtype='object')

# %%
from datetime import datetime

def convert_unix_to_datetime(unix_timestamp):
    dt_object = datetime.utcfromtimestamp(unix_timestamp)

    return dt_object.strftime('%Y-%m-%d %H:%M:%S')

df["time_submit"] = df["time_submit"].apply(convert_unix_to_datetime)

# %%
df.head(10)
# Out:
#            id_job    id_array_job  id_array_task         id_user  \
# 0  82691694838059  38873353215144           2504  42770088536256
# 1   3434806870797  38873353215144           2523  42770088536256
# 2   8370846758272  38873353215144           2543  42770088536256
# 3  50552783599355  16618712154521     4294967294  28063009141185
# 4  16051179268048  74939912707152           2625  42770088536256
# 5  26940411750496  16618712154521     4294967294  78105663882022
# 6  26419036762941  84173100828392              0  11289836447956
# 7  84007780551106  84173100828392              1  11289836447956
# 8  18898577480687  84173100828392              2  11289836447956
# 9  16601813966475  84173100828392              3  11289836447956
#
#       kill_requid  nodes_alloc              nodelist  cpus_req  derived_ec  \
# 0  61026541062099            1  ['r9189566-n911952']        20           0
# 1  61026541062099            1  ['r9189566-n911952']        20           0
# ...

# %%
df["time_submit"].min()
# Out:
# '2021-01-01 21:15:03'

# %%
df["time_submit"].max()
# Out:
# '2021-10-01 14:58:01'

# %%
df.tail()
# Out:
#                 id_job    id_array_job  id_array_task         id_user  \
# 395909  32038172524356  67754413936006            133  11051103666595
# 395910  70062821387698  67754413936006            203  11051103666595
# 395911  39278200520145  67754413936006            218  11051103666595
# 395912  20365469379943  67754413936006            270  11051103666595
# 395913  70535025316763  67754413936006            280  11051103666595
#
#            kill_requid  nodes_alloc              nodelist  cpus_req  \
# 395909  61026541062099            1   ['r697496-n325382']         1
# 395910  61026541062099            1  ['r1018283-n680758']         1
# 395911  61026541062099            1   ['r629115-n325382']         1
# 395912  61026541062099            1  ['r1018283-n680758']         1
# 395913  61026541062099            1   ['r406820-n680758']         1
#
#         derived_ec  exit_code  ...   timelimit          time_submit  \
# ...

# %%
df["time_end"] = df["time_end"].apply(convert_unix_to_datetime)
df.head()
# Out:
#            id_job    id_array_job  id_array_task         id_user  \
# 0  82691694838059  38873353215144           2504  42770088536256
# 1   3434806870797  38873353215144           2523  42770088536256
# 2   8370846758272  38873353215144           2543  42770088536256
# 3  50552783599355  16618712154521     4294967294  28063009141185
# 4  16051179268048  74939912707152           2625  42770088536256
#
#       kill_requid  nodes_alloc              nodelist  cpus_req  derived_ec  \
# 0  61026541062099            1  ['r9189566-n911952']        20           0
# 1  61026541062099            1  ['r9189566-n911952']        20           0
# 2  61026541062099            1  ['r9189566-n911952']        20           0
# 3  61026541062099            1  ['r2100214-n851693']         1           9
# 4  61026541062099            1  ['r9189566-n911952']        20           0
#
#    exit_code  ...   timelimit          time_submit  time_eligible  time_start  \
# ...

# %%
df.tail()
# Out:
#                 id_job    id_array_job  id_array_task         id_user  \
# 395909  32038172524356  67754413936006            133  11051103666595
# 395910  70062821387698  67754413936006            203  11051103666595
# 395911  39278200520145  67754413936006            218  11051103666595
# 395912  20365469379943  67754413936006            270  11051103666595
# 395913  70535025316763  67754413936006            280  11051103666595
#
#            kill_requid  nodes_alloc              nodelist  cpus_req  \
# 395909  61026541062099            1   ['r697496-n325382']         1
# 395910  61026541062099            1  ['r1018283-n680758']         1
# 395911  61026541062099            1   ['r629115-n325382']         1
# 395912  61026541062099            1  ['r1018283-n680758']         1
# 395913  61026541062099            1   ['r406820-n680758']         1
#
#         derived_ec  exit_code  ...   timelimit          time_submit  \
# ...
